# %% [markdown]
# <h1><font color='lightblue'>IT Betyár - Gépi tanulás</font></h1>
#
# <img src="https://www.itbetyar.hu/dload_itb/itbetyar-cifar10-minta.webp" alt="IT Betyár Cifar minta" width="400"><br>
#
#
# <a href="https://itbetyar.hu/mesterseges-intelligencia-fejleszto-tanfolyam/" target="_blank" style="color: lightpink; text-decoration: underline;"><u>Tanfolyam honlap >> </u></a><br>
#
#   <table align="left" style="border-collapse: separate;  padding: 10px;">
#     <td>
#       <a target="_blank" href="https://itbetyar.hu" style="color: lightcyan;"><img src="https://itbetyar.hu/dload_itb/itb_logo70.webp" width="30px" /> Honlap - ITBetyar.hu </a>
#     </td>
#     <td>
#       <a target="_blank" href="https://github.com/itbetyar" style="color: lightcyan;"><img src="https://itbetyar.hu/dload_itb/githublogo.webp" width="33px"/>ITB - GitHub</a>
#     </td>
#   </table><br>
# <br>
# <h3><font color='lightpink'>Ingyenes minta lecke : </font><font color='lightcyan'>CNN Alapok - Cifar10 - IT Betyár </font></h3>
#
#
# ---
#
#
# <h3><font color='lightcyan'>Neurális háló feltanítása és tesztelése</font></h3>
#
# 1.   Bevezetés a mesterséges intelligencia fejlesztésbe
# 2.   **Neurális háló** feltanítása
# 3.   A létrehozott modell tesztelése
#
# Autó, kutya, béka, repülő, macska, szarvas ... stb. beazonosítása
#
# ----
# <h3>📚  <font color='lightpink'>1. Első lépés: A szükséges programozási könyvtárak importálása</font></h3>

# %%
import tensorflow as tf
from keras import datasets, layers, models
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <h3>💽 <font color='lightpink'>2. lépés - A tanítási adatok - adatállomány betöltése</font></h3>
#
#
# *   A gépi tanuláshoz rengeteg adatra, jelen esetben képre van szükség.<br>
# *   A torontói egyetem jóvoltából létezik a "CIFAR10" névre hallgató képállomány.<br>
#
# Benne 60,000 felvétel. Mivel ez egy tanulásra előkészített adat, ezért egy sor kóddal ezt be tudjuk tölteni.

# %%
(X_train, y_train), (X_test,y_test) = datasets.cifar10.load_data()

# %% [markdown]
# <h3><font color='lightpink'>3. A neurális hálózat (NN) felépítése tanuláshoz</font></h3>
# Alábbi kódban meghatározzuk az NN rétegeit és a tanulási folyamat főbb paramétereit.

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

cnn = models.Sequential([
    layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

cnn.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = cnn.fit(X_train, y_train, epochs=8, validation_data=(X_test, y_test))
print("Lefutott a tanulás mehetsz tovább")
# FONTOS >> A tanitas lefutasat meg kell varni ez tobb percet vesz igenybe

# %% [markdown]
# ---
# <h3><font color='lightcyan'>Fontos!! Tesztelés előtt várd meg a</font><br> "Lefutott a tanulás mehetsz tovább" kiírást</h3>
#
# ---
# <h1><font color='lightblue'>Tesztelés</font></h1>
# <h3><font color='lightpink'>4. A feltanított neurális háló tesztelése</font></h3>
# Itt elsőre a feltanításhoz is használt 'cifar10' adatset, teszt részében szereplő képek közül választunk ki párat random.<br> Majd megkérjük a frissen feltanított modellt, hogy állapítsa meg, hogy mi található a képen?!
# <p><font color='lightpink'>Itt is csak nyomd meg a play gombot, a kis tesztképek meg fognak jelenni a kód alatt!</font></p>

# %%
def display_images(images, labels, predictions, classes, num_images=5):
    plt.figure(figsize=(8, 2))
    for i in range(num_images):
        plt.subplot(1, num_images, i + 1)
        plt.imshow(images[i])
        plt.title(f"True: {classes[labels[i][0]]}\nPredicted: {classes[predictions[i]]}")
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# Pár kép random kiválasztása a teszt adatállományból
num_images_to_display = 5
random_indices = np.random.choice(len(X_test), num_images_to_display, replace=False)
images_to_display = X_test[random_indices]
labels_to_display = y_test[random_indices]

predictions = np.argmax(cnn.predict(images_to_display), axis=-1)

display_images(images_to_display, labels_to_display, predictions, classes)

# %% [markdown]
# <h3><font color='lightpink'>5.1 Saját teszt fájlok betöltése</font> 💾 </h3>
# Csak futtasd az alábbi kódot és pár mintakép letöltődik az IT Betyár github oldaláról.<br>
#
#
# *Nem a Te gépedre töltődik le, hanem a Colab felületére*

# %%
# !mkdir -p test1 test2
# !git clone --depth 1 --filter=blob:none --sparse https://github.com/itbetyar/Neuralis_Halo_Cifar10.git
# %cd Neuralis_Halo_Cifar10
# !git sparse-checkout set test1 test2
# !mv test1/* ../test1/
# !mv test2/* ../test2/
# !rm -rf test1 test2 .git
# %cd ..
# !rm -rf Neuralis_Halo_Cifar10
# !rm -rf sample_data

# %% [markdown]
# <h3><font color='lightpink'>5.2 Az előbbi lépésben feltöltött képeket tesztelheted itt</font></h3>

# %%
from keras.preprocessing.image import load_img, img_to_array
import io
import os

# A fenti lépésben letöltött teszt mappát itt át tudod írni ha szeretnéd
test_folder = '/content/test1'  #

num_images_to_display = len(os.listdir(test_folder))  # Number of images in the 'test1' folder
plt.figure(figsize=(10, 3))

for idx, filename in enumerate(os.listdir(test_folder), start=1):
    file_path = os.path.join(test_folder, filename)
    plt.subplot(2, num_images_to_display, idx)

    orig_img = load_img(file_path)
    img = load_img(file_path, target_size=(32, 32))  # Target size
    img_array = img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    processed_img = img_array / 255.0  # Normalization

    prediction = cnn.predict(processed_img)
    predicted_class = np.argmax(prediction)

    plt.imshow(orig_img)
    plt.axis('off')
    predicted_label = classes[predicted_class]

    text_y = orig_img.size[1] + 90
    plt.text(10, text_y, f"{predicted_label}", fontsize=16)

plt.show()

# %% [markdown]
# ## 🏆 A lecke végére értél, gratulálunk a sikeres lecke teljesítéshez!
#
# Várunk szeretettel képzéseinken!<br>
# <a href="https://itbetyar.hu/mesterseges-intelligencia-fejleszto-tanfolyam/" target="_blank"><img src="https://www.itbetyar.hu/dload_itb/aidev-banner500.webp" alt="IT Betyár Cifar minta" width="300"></a>
#
#
# <h1><font color='lightblue'>IT Betyár - Gépi tanulás</font></h1>
#
# <img src="https://www.itbetyar.hu/dload_itb/itbetyar-cifar10-minta.webp" alt="IT Betyár Cifar minta" width="400"><br>
#
#
# <a href="https://itbetyar.hu/mesterseges-intelligencia-fejleszto-tanfolyam/" target="_blank" style="color: lightpink; text-decoration: underline;"><u>Tanfolyam honlap >> </u></a><br>
#
#   <table align="left" style="border-collapse: separate;  padding: 10px;">
#     <td>
#       <a target="_blank" href="https://itbetyar.hu" style="color: lightcyan;"><img src="https://itbetyar.hu/dload_itb/itb_logo70.webp" width="30px" /> Honlap - ITBetyar.hu </a>
#     </td>
#     <td>
#       <a target="_blank" href="https://github.com/itbetyar" style="color: lightcyan;"><img src="https://itbetyar.hu/dload_itb/githublogo.webp" width="33px"/>ITB - GitHub</a>
#     </td>
#   </table>
